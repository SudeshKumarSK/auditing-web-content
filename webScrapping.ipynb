# %% [markdown]
# # DATAFEST 2023!
# ## AUDITING WEB CONTENT PROMOTING EATING DISORDERS
# ### WEB SCRAPPING TO COLLECT DATA FROM TUMBLR MICRO-BLOGGING SITE.

# %%
#Importing all necessary libraries.
import matplotlib.pyplot as plt
from utils.tumblrEngine import TumblrEngine
import pytumblr

# %%
# Api Details for Tumblr:

OAuth_Consumer_Key = "fQ6XFOUgYTGJGDN1gzAJODDDfnsh1rBoC9j5NNNUMYSGoNSjfX"
OAuth_Consumer_Secret = "zIpneiKXuUwCjgO06az2Ulu2i09NDxxNfnTk1S0nttUCTEEtcX"

apiDetails = {
    "OAuth_Consumer_Key" : "fQ6XFOUgYTGJGDN1gzAJODDDfnsh1rBoC9j5NNNUMYSGoNSjfX",
    "OAuth_Consumer_Secret" : "zIpneiKXuUwCjgO06az2Ulu2i09NDxxNfnTk1S0nttUCTEEtcX"
}

# %% [markdown]
# ## Creating an instance for the TumblrEngine class()

# %%
tumblrScraper = TumblrEngine(apiDetails)

# %%
response = tumblrScraper.getTaggedPostsUserData(tagName="thispo", timestamp=1665276480)

# %%
response
# Out:
# {'status': True,
#  'response': {0: {'blog_name': 'iwannabeskinysblog',
#    'user_id': 697586838038282240},
#   1: {'blog_name': 'iwannabeskinysblog', 'user_id': 697586837962833921},
#   2: {'blog_name': 'massivekryptonitechaos', 'user_id': 697554241939783680},
#   3: {'blog_name': 'massivekryptonitechaos', 'user_id': 697463605412642816},
#   4: {'blog_name': 'elorexia', 'user_id': 697028001889665024},
#   5: {'blog_name': 'princesamagra', 'user_id': 696601288015790080},
#   6: {'blog_name': 'imfartooobsessedwithkpop', 'user_id': 696528029686611968},
#   7: {'blog_name': 'dziennikanorekryczki', 'user_id': 696384592170647552},
#   8: {'blog_name': 'idubisanaanaisdead', 'user_id': 695912212789854208},
#   9: {'blog_name': '123dontbeme', 'user_id': 695740156221718528},
#   10: {'blog_name': 'ru1nedkitten', 'user_id': 695231765860745216},
#   11: {'blog_name': 'dziennikanorekryczki', 'user_id': 694936897873756160},
#   12: {'blog_name': 'imfartooobsessedwithkpop', 'user_id': 694028848929685504},
#   13: {'blog_name': 'ru1nedkitten', 'user_id': 693506799289221120},
#   14: {'blog_name': 'massivekryptonitechaos', 'user_id': 693454701834993664},
#   15: {'blog_name': 'iamnotsos-blog', 'user_id': 693329189420564480},
#   16: {'blog_name': 'an0retyczk', 'user_id': 692496582892044288},
#   17: {'blog_name': 'an0retyczk', 'user_id': 692445925134761984},
#   18: {'blog_name': 'an0retyczk', 'user_id': 692405434192216064},
#   19: {'blog_name': 'lundbuddhi', 'user_id': 691666767832055808}},
#  'length': 20,
#  'timestamp': 1659624831}
